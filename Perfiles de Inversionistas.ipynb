# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.neighbors import KernelDensity
import datetime
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %%
# Función para descargar precios de cierre ajustados:
def get_adj_closes(tickers, start_date=None, end_date=None):
    # Fecha inicio por defecto (start_date='2010-01-01') y fecha fin por defecto (end_date=today)
    # Descargamos DataFrame con todos los datos
    closes = web.DataReader(name=tickers, data_source='yahoo', start=start_date, end=end_date)
    # Solo necesitamos los precios ajustados en el cierre
    closes = closes['Adj Close']
    # Se ordenan los índices de manera ascendente
    closes.sort_index(inplace=True)
    return closes

# %%
names=['FGEN','ENPSX','HISFX']
start='2016-01-01'

# %%
closesmod=get_adj_closes(tickers=names,
                     start_date=start
                     )
closesmod.head()
# Out:
# Symbols      FGEN      ENPSX      HISFX
# Date
# 2016-01-04  30.50  25.581135  12.216651
# 2016-01-05  30.07  25.747883  12.263603
# 2016-01-06  27.07  24.276573  12.235431
# 2016-01-07  27.07  23.393789  11.991287
# 2016-01-08  26.00  22.952396  11.831653

# %%
closesmod.plot(figsize=(8,6),grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ret=closesmod.pct_change().dropna()
ret.head()
# Out:
# Symbols         FGEN     ENPSX     HISFX
# Date
# 2016-01-05 -0.014098  0.006518  0.003843
# 2016-01-06 -0.099767 -0.057143 -0.002297
# 2016-01-07  0.000000 -0.036364 -0.019954
# 2016-01-08 -0.039527 -0.018868 -0.013313
# 2016-01-11 -0.035385 -0.032479  0.001587

# %%
ret.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
names=['CORN','GOLD','AAPL']
start='2016-01-01'

# %%
closesCON=get_adj_closes(tickers=names,
                     start_date=start
                     )
closesCON.head()
# Out:
# Symbols          CORN      GOLD       AAPL
# Date
# 2016-01-04  20.879999  7.278697  24.323219
# 2016-01-05  20.910000  7.184780  23.713696
# 2016-01-06  20.870001  7.457143  23.249626
# 2016-01-07  20.920000  8.217884  22.268383
# 2016-01-08  21.139999  7.907953  22.386133

# %%
closesCON.plot(figsize=(8,6),grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ret=closesCON.pct_change().dropna()
ret.head()
# Out:
# Symbols         CORN      GOLD      AAPL
# Date
# 2016-01-05  0.001437 -0.012903 -0.025059
# 2016-01-06 -0.001913  0.037908 -0.019570
# 2016-01-07  0.002396  0.102015 -0.042205
# 2016-01-08  0.010516 -0.037714  0.005288
# 2016-01-11 -0.014664 -0.032067  0.016193

# %%
ret.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
names=['TSLA','^IXIC','MSFT']
start='2016-01-01'

# %%
closes=get_adj_closes(tickers=names,
                     start_date=start
                     )
closes.head()
# Out:
# Symbols          TSLA        ^IXIC       MSFT
# Date
# 2016-01-04  44.681999  4903.089844  49.776890
# 2016-01-05  44.686001  4891.430176  50.003983
# 2016-01-06  43.807999  4835.759766  49.095642
# 2016-01-07  43.130001  4689.430176  47.387970
# 2016-01-08  42.200001  4643.629883  47.533310

# %%
closes.plot(figsize=(8,6),grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ret=closes.pct_change().dropna()
ret.head()
# Out:
# Symbols         TSLA     ^IXIC      MSFT
# Date
# 2016-01-05  0.000090 -0.002378  0.004562
# 2016-01-06 -0.019648 -0.011381 -0.018165
# 2016-01-07 -0.015477 -0.030260 -0.034783
# 2016-01-08 -0.021563 -0.009767  0.003067
# 2016-01-11 -0.014929 -0.001214 -0.000573

# %%
ret.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
